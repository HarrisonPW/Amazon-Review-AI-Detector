# %% [markdown]
# # This file is used for data reprocessing

# %% [markdown]
# #### selecting 20,000 from each category, where each contains 10,000 spam and 10,000 not spam

# %%
# import
import json
import random
import os

import nltk
nltk.download('stopwords')
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
import re

import pandas as pd
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/zhuzilu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Function to load and process a single JSON file
def process_json_file(file_path, outputfile, num_samples_per_class=10000):
    """
    Processes a JSON file and selects a specified number of samples for each class (e.g., 'spam', 'not spam').

    Args:
        file_path (str): Path to the JSON file.
        output_dir (str): Directory where the processed file will be saved.
        num_samples_per_class (int): Number of samples to select for each class.

    Returns:
        None
    """
    with open(file_path, 'r') as f:
        data = [json.loads(line.strip()) for line in f]

    # Separate data into spam and not spam based on the 'class' label
    spam_data = [item for item in data if item.get('class') == 1.0]
    not_spam_data = [item for item in data if item.get('class') == 0.0]

    # Randomly sample the specified number of rows for each class
    sampled_spam = random.sample(spam_data, min(num_samples_per_class, len(spam_data)))
    sampled_not_spam = random.sample(not_spam_data, min(num_samples_per_class, len(not_spam_data)))

    # Combine sampled data
    selected_data = sampled_spam + sampled_not_spam

    # Shuffle the combined data
    random.shuffle(selected_data)

    ps = PorterStemmer() # initializing porter stemmer

    # Save the processed data to a new JSON file
    df = pd.DataFrame(selected_data)
    df = df[['category','summary','reviewText','class']]
    corpus=[]
    # sentences=[]
    for i in range(len(df)):
        review=re.sub('[^a-zA-Z]',' ', df['reviewText'][i])
        review=review.lower()
        list=review.split()
        review=[ps.stem(word) for word in list if word not in set(stopwords.words('english'))]
        sentences=' '.join(review)
        corpus.append(sentences)
    df['reviewTextEdit'] = corpus

    df.to_json(outputfile, orient='records', lines=True)


    # with open(outputfile, 'a') as f:
    #     json.dump(df, f)

    print(f"Processed file saved to {outputfile}")

# %%
process_json_file('dataset_files/Clothing_Shoes_and_Jewelry.json', 'dataset_files/processeddata_clothing.json')
# Out:
# Processed file saved to dataset_files/processeddata_clothing.json

# %%
process_json_file('dataset_files/Home_and_Kitchen.json', 'dataset_files/processeddata_home.json')
# Out:
# Processed file saved to dataset_files/processeddata_home.json

# %%
process_json_file('dataset_files/Sports_and_Outdoors.json', 'dataset_files/processeddata_sports.json')
# Out:
# Processed file saved to dataset_files/processeddata_sports.json

# %%
process_json_file('dataset_files/Toys_and_Games.json', 'dataset_files/processeddata_toys.json')
# Out:
# Processed file saved to dataset_files/processeddata_toys.json

# %%
with open('dataset_files/Cell_Phones_and_Accessories.json', 'r') as f:
    data = [json.loads(line.strip()) for line in f]
data[0]
# Out:
# {'_id': {'$oid': '5a1321d5741a2384e802c552'},
#  'reviewerID': 'A3HVRXV0LVJN7',
#  'asin': '0110400550',
#  'reviewerName': 'BiancaNicole',
#  'helpful': [4, 4],
#  'reviewText': 'Best phone case ever . Everywhere I go I get a ton of compliments on it. It was in perfect condition as well.',
#  'overall': 5.0,
#  'summary': 'A++++',
#  'unixReviewTime': 1358035200,
#  'reviewTime': '01 13, 2013',
#  'category': 'Cell_Phones_and_Accessories',
#  'class': 1.0}

# %%
spam_data = [item for item in data if item.get('class') == 1.0]

# %%
not_spam_data = [item for item in data if item.get('class') == 0.0]

# Randomly sample the specified number of rows for each class
sampled_spam = random.sample(spam_data, min(10000, len(spam_data)))
sampled_not_spam = random.sample(not_spam_data, min(10000, len(not_spam_data)))

# Combine sampled data
selected_data = sampled_spam + sampled_not_spam

# Shuffle the combined data
random.shuffle(selected_data)

# %%
len(selected_data)
# Out:
# 20000

# %%
ps = PorterStemmer() # initializing porter stemmer

# %%
selected_data[0].get('reviewText')
# Out:
# "Love it. Really worth the money .hasn't bubbled up or anything..... it's a great product. .. you should try it"

# %%
df = pd.DataFrame(selected_data)
df = df[['category','summary','reviewText','class']]
corpus=[]
# sentences=[]
for i in range(len(df)):
    review=re.sub('[^a-zA-Z]',' ', df['reviewText'][i])
    review=review.lower()
    list=review.split()
    review=[ps.stem(word) for word in list if word not in set(stopwords.words('english'))]
    sentences=' '.join(review)
    corpus.append(sentences)
df['reviewTextEdit'] = corpus

# %%
corpus=[]
# sentences=[]
for i in range(len(df)):

    review=re.sub('[^a-zA-Z]',' ', df['reviewText'][i])
    review=review.lower()
    list=review.split()
    review=[ps.stem(word) for word in list if word not in set(stopwords.words('english'))]
    sentences=' '.join(review)
    corpus.append(sentences)

# %%
df['reviewTextEdit'] = corpus

# %%
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df.head(5)
#
# NameError: name 'df' is not defined

# %%
df.to_json('dataset_files/processeddata_cell.json', orient='records', lines=True)

# %% [markdown]
# # MSE

# %%
with open('dataset_files/final_logisticregression.json', 'r') as f:
    d = [json.loads(line.strip()) for line in f]
d[75721]
# Out:
# {'category': 'Sports_and_Outdoors',
#  'summary': 'Oris Rocks!!!',
#  'reviewText': 'I love it. Great watch! The size is perfect. It is a beautiful and excellent quality watch. I am in love with Oris! Oris Rocks!!!',
#  'class': 1.0,
#  'reviewTextEdit': 'love great watch size perfect beauti excel qualiti watch love ori ori rock',
#  'text_length': 74,
#  'predicted_label': None,
#  'predict_value': 0.0}

# %%
d_df = pd.DataFrame(d)

# %%
d_df['predict_value'].tail(20000).isnull().sum()
# Out:
# 20000

# %%
d_df['category'].tail(20000).unique()
# Out:
# array(['Toys_and_Games'], dtype=object)

# %%
with open('dataset_files/final_GPT2.json', 'r') as f:
    d2 = [json.loads(line.strip()) for line in f]
d2[75721]
# Out:
# {'category': 'Sports_and_Outdoors',
#  'summary': 'Oris Rocks!!!',
#  'reviewText': 'I love it. Great watch! The size is perfect. It is a beautiful and excellent quality watch. I am in love with Oris! Oris Rocks!!!',
#  'class': 1.0,
#  'reviewTextEdit': 'love great watch size perfect beauti excel qualiti watch love ori ori rock',
#  'predict_value': 0}

# %%
d2_df = pd.DataFrame(d2)
print(d2_df['predict_value'].isnull())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99995     True
# 99996     True
# 99997     True
# 99998     True
# 99999     True
# Name: predict_value, Length: 100000, dtype: bool

# %%
d3 = pd.read_csv('dataset_files/final_bertlstm.csv')

# %%
d3['predicted_class'].isnull().sum()
# Out:
# 20000

# %%
d3['reviewText'][75721]
# Out:
# 'I love it. Great watch! The size is perfect. It is a beautiful and excellent quality watch. I am in love with Oris! Oris Rocks!!!'

# %%
with open('dataset_files/final_NB.json', 'r') as f:
    d4 = [json.loads(line.strip()) for line in f]
d4[75721]
# Out:
# {'category': 'Sports_and_Outdoors',
#  'summary': 'Oris Rocks!!!',
#  'reviewText': 'I love it. Great watch! The size is perfect. It is a beautiful and excellent quality watch. I am in love with Oris! Oris Rocks!!!',
#  'class': 1.0,
#  'reviewTextEdit': 'love great watch size perfect beauti excel qualiti watch love ori ori rock',
#  'predict_value_NB': 1.0}

# %%
finaldf = pd.DataFrame(d4)

# %%
finaldf['predict_value_logistic'] = pd.DataFrame(d)['predict_value']

# %%
finaldf['predict_value_gpt2'] = pd.DataFrame(d2)['predict_value']

# %%
finaldf['predict_value_bertlstm'] = d3['predicted_class']

# %%
finaldf.head(5)
# Out:
#                       category                                 summary  \
# 0  Cell_Phones_and_Accessories                                    yess
# 1  Cell_Phones_and_Accessories                  Faulty SIM card reader
# 2  Cell_Phones_and_Accessories                   sturdy and functional
# 3  Cell_Phones_and_Accessories  The white case I've been looking for..
# 4  Cell_Phones_and_Accessories                              It's cool.
#
#                                           reviewText  class  \
# 0  Love it. Really worth the money .hasn't bubble...    0.0
# 1  Let me start by saying that I am and will alww...    0.0
# 2  love this holster. It kept my phone accessable...    1.0
# 3  This is my third white case I've purchased. I ...    1.0
# 4  I just got it today so I will use it soon but ...    1.0
#
#                                       reviewTextEdit  predict_value_NB  \
# 0  love realli worth money bubbl anyth great prod...               1.0
# 1  let start say alwway fan nokia symbian oper sy...               0.0
# 2  love holster kept phone access protect easi at...               1.0
# 3  third white case purchas purchasedwireless cen...               0.0
# 4  got today use soon littl disappoint expect lit...               0.0
#
#    predict_value_logistic  predict_value_gpt2  predict_value_bertlstm
# 0                     1.0                 0.0                     1.0
# 1                     0.0                 0.0                     0.0
# 2                     0.0                 0.0                     1.0
# 3                     0.0                 1.0                     1.0
# 4                     1.0                 1.0                     0.0

# %%
finaldf.to_json('dataset_files/finaldf.json', orient='records', lines=True)

# %%
test_df = pd.read_csv('dataset_files/test_df.csv')

# %%
test_df
# Out:
#        Unnamed: 0  index                     category  \
# 0               0  43410             Home_and_Kitchen
# 1              10   4998  Cell_Phones_and_Accessories
# 2              11  15044  Cell_Phones_and_Accessories
# 3              12  85819               Toys_and_Games
# 4              13  65232          Sports_and_Outdoors
# ...           ...    ...                          ...
# 19995       99982  33413   Clothing_Shoes_and_Jewelry
# 19996       99983  50329             Home_and_Kitchen
# 19997       99992  40681             Home_and_Kitchen
# 19998       99993  55616             Home_and_Kitchen
# 19999       99998  20149   Clothing_Shoes_and_Jewelry
#
#                                                  summary  \
# 0                                            Good but...
# 1                                    Just don't do it!!!
# 2                                Not worth consideration
# 3      This is not a true 1/16 scale model. It is muc...
# 4                           Ecstatic two-tone case owner
# ...                                                  ...
# 19995                           you get what you pay for
# 19996                                        Corn holder
# 19997                      Pricing is crazy on this item
# 19998                                              awful
# 19999                                   I bought another
#
#                                               reviewText  class  \
# 0      ! Great little fondue set! It's so cute! My on...      1
# 1      "Ditto" to the comment "there wasn't a choice ...      0
# 2      "Eh, it's only a few bucks, worth a shot!"WRON...      0
# 3      "Extremely" upset when I opened the box. It's ...      0
# 4      "First, I am overjoyed to find a case for such...      1
# ...                                                  ...    ...
# 19995  you get what you pay for. makes everything yel...      0
# 19996  you get what you pay for...it was inexpensive ...      0
# 19997  you've got to be nuts to think someone will pa...      0
# 19998  you;d think that a cookbook stand would hold m...      0
# 19999  zumba brand bra of a different style and it fi...      0
#
#                                           reviewTextEdit  text_length  \
# 0      great littl fondu set cute complaint new crack...          168
# 1      ditto comment choic zero product would gotten ...          455
# 2      eh buck worth shot wrong use batteri accur com...           99
# 3      extrem upset open box even close expect scale ...          234
# 4      first overjoy find case good price especi ad f...          395
# ...                                                  ...          ...
# 19995  get pay make everyth yellow glare actual seem ...           87
# 19996  get pay inexpens felt way prevent corn roll ar...           50
# 19997         got nut think someon pay towel materi gold           42
# 19998  think cookbook stand would hold narrowest book...          180
# 19999  zumba brand bra differ style fit perfectli loo...           72
#
#        predict_value_gpt2  predict_value_logistic  predict_value_NB  \
# 0                       1                       1                 1
# 1                       0                       1                 0
# 2                       0                       1                 0
# 3                       0                       1                 0
# 4                       1                       0                 1
# ...                   ...                     ...               ...
# 19995                   0                       1                 0
# 19996                   1                       0                 0
# 19997                   0                       0                 0
# 19998                   0                       0                 0
# 19999                   1                       0                 1
#
#        predict_value_bertlstm  predict_bagging  predict_bagging_binary
# 0                           1         1.000000                       1
# 1                           0         0.040050                       0
# 2                           0         0.040050                       0
# 3                           0         0.040050                       0
# 4                           1         0.959950                       1
# ...                       ...              ...                     ...
# 19995                       0         0.040050                       0
# 19996                       0         0.331500                       0
# 19997                       0         0.000000                       0
# 19998                       0         0.000000                       0
# 19999                       0         0.463134                       0
#
# [20000 rows x 14 columns]

# %%
print(test_df['reviewTextEdit'])
# Out:
# 0        great littl fondu set cute complaint new crack...
# 1        ditto comment choic zero product would gotten ...
# 2        eh buck worth shot wrong use batteri accur com...
# 3        extrem upset open box even close expect scale ...
# 4        first overjoy find case good price especi ad f...
#                                ...
# 19995    get pay make everyth yellow glare actual seem ...
# 19996    get pay inexpens felt way prevent corn roll ar...
# 19997           got nut think someon pay towel materi gold
# 19998    think cookbook stand would hold narrowest book...
# 19999    zumba brand bra differ style fit perfectli loo...
# Name: reviewTextEdit, Length: 20000, dtype: object

# %%
test_df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'category', 'summary', 'reviewText', 'class',
#        'reviewTextEdit', 'text_length', 'predict_value_gpt2',
#        'predict_value_logistic', 'predict_value_NB', 'predict_value_bertlstm',
#        'predict_bagging', 'predict_bagging_binary'],
#       dtype='object')

# %%
filtered_df = test_df[
    (test_df['predict_value_gpt2'] == 0) &
    (test_df['predict_value_logistic'] == 0) &
    (test_df['predict_value_NB'] == 0) &
    (test_df['predict_value_bertlstm'] == 0) &
    (test_df['class'] == 1)
]
filtered_df
# Out:
#        Unnamed: 0  index                    category  \
# 8              38  70237         Sports_and_Outdoors
# 9              40  56180            Home_and_Kitchen
# 16             60  36435  Clothing_Shoes_and_Jewelry
# 21             83  36293  Clothing_Shoes_and_Jewelry
# 23             88  52595            Home_and_Kitchen
# ...           ...    ...                         ...
# 19987       99937  64639         Sports_and_Outdoors
# 19991       99953  24455  Clothing_Shoes_and_Jewelry
# 19992       99961  87190              Toys_and_Games
# 19997       99992  40681            Home_and_Kitchen
# 19998       99993  55616            Home_and_Kitchen
#
#                                                  summary  \
# 8                       Math problems are not your forte
# 9                    Product is expensive for what it is
# 16                                     poor construction
# 21                  I wish I had gotten something better
# 23     Wanted to like this thing, but it smells terrible
# ...                                                  ...
# 19987                                                wow
# 19991  The Mountain Men's Rottweiler Face T-shirt xxx...
# 19992             Works of AHHH Treasure chest Coin bank
# 19997                      Pricing is crazy on this item
# 19998                                              awful
#
#                                               reviewText  class  \
# 8      $3500 / 100 wheels = $35 per wheel...It shows ...      0
# 9      $40 for these shelves are too expensive. they ...      0
# 16     ($59.99 on Easy Spirit website) wore these twi...      0
# 21     ********UPDATE**********I would consider this ...      0
# 23     ***Instead of returning it yet Im ordering ano...      0
# ...                                                  ...    ...
# 19987  wow we have had this item for about a year and...      0
# 19991  xxx-large not! xxx-long yes my son love rotti'...      0
# 19992  yes there is paint to decorate and paint your ...      0
# 19997  you've got to be nuts to think someone will pa...      0
# 19998  you;d think that a cookbook stand would hold m...      0
#
#                                           reviewTextEdit  text_length  \
# 8      wheel per wheel show msrp per wheel umm someon...           68
# 9      shelv expens shelv hold screw instruct poor do...          103
# 16     easi spirit websit wore twice sneaker came apa...          129
# 21     updat would consid bag inferior exact one repl...         1217
# 23     instead return yet im order anoth hepa filter ...         1326
# ...                                                  ...          ...
# 19987  wow item year roof fell apart littl piec cost ...           63
# 19991  xxx larg xxx long ye son love rotti bought lb ...          243
# 19992  ye paint decor paint design enough paint paint...          189
# 19997         got nut think someon pay towel materi gold           42
# 19998  think cookbook stand would hold narrowest book...          180
#
#        predict_value_gpt2  predict_value_logistic  predict_value_NB  \
# 8                       0                       0                 0
# 9                       0                       0                 0
# 16                      0                       0                 0
# 21                      0                       0                 0
# 23                      0                       0                 0
# ...                   ...                     ...               ...
# 19987                   0                       0                 0
# 19991                   0                       0                 0
# 19992                   0                       0                 0
# 19997                   0                       0                 0
# 19998                   0                       0                 0
#
#        predict_value_bertlstm  predict_bagging  predict_bagging_binary
# 8                           0              0.0                       0
# 9                           0              0.0                       0
# 16                          0              0.0                       0
# 21                          0              0.0                       0
# 23                          0              0.0                       0
# ...                       ...              ...                     ...
# 19987                       0              0.0                       0
# 19991                       0              0.0                       0
# 19992                       0              0.0                       0
# 19997                       0              0.0                       0
# 19998                       0              0.0                       0
#
# [3753 rows x 14 columns]

# %%
test_df[
    (test_df['predict_value_gpt2'] == 1) &
    (test_df['predict_value_logistic'] == 1) &
    (test_df['predict_value_NB'] == 1) &
    (test_df['predict_value_bertlstm'] == 1) &
    (test_df['class'] == 0)
]
# Out:
#        Unnamed: 0  index                     category  \
# 89            451   4472  Cell_Phones_and_Accessories
# 106           551  86712               Toys_and_Games
# 348          1788  35718   Clothing_Shoes_and_Jewelry
# 361          1853  24481   Clothing_Shoes_and_Jewelry
# 484          2406  34250   Clothing_Shoes_and_Jewelry
# ...           ...    ...                          ...
# 19574       97966    831  Cell_Phones_and_Accessories
# 19740       98789  70398          Sports_and_Outdoors
# 19802       99083  30854   Clothing_Shoes_and_Jewelry
# 19819       99144  30867   Clothing_Shoes_and_Jewelry
# 19829       99230  69435          Sports_and_Outdoors
#
#                                                  summary  \
# 89                                                  Good
# 106                             Great in or outdoor toy!
# 348    New Balance Men's MO889 Outdoor Multisport Hik...
# 361    I want my child to grow up to be just like Mic...
# 484                                       a good product
# ...                                                  ...
# 19574                        Works but just a bit flimsy
# 19740                                     good kickstand
# 19802                                         UGLY WATCH
# 19819                                                mac
# 19829                                      strange usage
#
#                                               reviewText  class  \
# 89     A bit too rubbery. Gets caught on fabric. Defi...      0
# 106    A fun toy for a ride inside or around the bloc...      0
# 348    Aloha, normally I take a size 7.52E which fits...      0
# 361    Although Michael Jackson was an admitted child...      0
# 484    Arrived sooner than expected, looks pretty str...      0
# ...                                                  ...    ...
# 19574  the stylus works and glides smoothly on my pho...      0
# 19740  this kickstand was an easy installed and works...      0
# 19802  this watch is even uglier in person, but it do...      0
# 19819  too small for me but a very nice purse the lea...      0
# 19829  using for unique place on houseboat,  needs to...      0
#
#                                           reviewTextEdit  text_length  \
# 89     bit rubberi get caught fabric definit protect ...           78
# 106    fun toy ride insid around block perfect clock ...           63
# 348    aloha normal take size e fit perfectli seem co...          268
# 361    although michael jackson admit child molest di...          266
# 484    arriv sooner expect look pretti strong price p...          232
# ...                                                  ...          ...
# 19574  stylu work glide smoothli phone screen silicon...          139
# 19740  kickstand easi instal work enough tension keep...           68
# 19802  watch even uglier person job number huge win f...          104
# 19819  small nice purs leather littl stiff might brea...           52
# 19829  use uniqu place houseboat need littl bigger re...           71
#
#        predict_value_gpt2  predict_value_logistic  predict_value_NB  \
# 89                      1                       1                 1
# 106                     1                       1                 1
# 348                     1                       1                 1
# 361                     1                       1                 1
# 484                     1                       1                 1
# ...                   ...                     ...               ...
# 19574                   1                       1                 1
# 19740                   1                       1                 1
# 19802                   1                       1                 1
# 19819                   1                       1                 1
# 19829                   1                       1                 1
#
#        predict_value_bertlstm  predict_bagging  predict_bagging_binary
# 89                          1              1.0                       1
# 106                         1              1.0                       1
# 348                         1              1.0                       1
# 361                         1              1.0                       1
# 484                         1              1.0                       1
# ...                       ...              ...                     ...
# 19574                       1              1.0                       1
# 19740                       1              1.0                       1
# 19802                       1              1.0                       1
# 19819                       1              1.0                       1
# 19829                       1              1.0                       1
#
# [278 rows x 14 columns]

# %%
test_df[
    (test_df['predict_bagging_binary'] == 0) &
    (test_df['class'] == 1)
].sample(10)
# Out:
#        Unnamed: 0  index                     category  \
# 2108        10344  83890               Toys_and_Games
# 13974       69825  90376               Toys_and_Games
# 5128        25605  26211   Clothing_Shoes_and_Jewelry
# 10118       50577  45446             Home_and_Kitchen
# 17908       89518  11727  Cell_Phones_and_Accessories
# 8030        40295  44593             Home_and_Kitchen
# 14481       72470  37026   Clothing_Shoes_and_Jewelry
# 10526       52674  43857             Home_and_Kitchen
# 17889       89429  37104   Clothing_Shoes_and_Jewelry
# 9479        47349  16736  Cell_Phones_and_Accessories
#
#                                          summary  \
# 2108         Decent Quality and Easy to Assemble
# 13974                             Goku Model Kit
# 5128                                      great!
# 10118             "may contain cosmetic defects"
# 17908                        The Headset To Beat
# 8030   Great for jerky; not so great for fruits.
# 14481                                  Run small
# 10526                             Microwave Oven
# 17889                                       thin
# 9479                         Launch Date Delayed
#
#                                               reviewText  class  \
# 2108   From reading some of the previous reviews, I w...      1
# 13974  There are a lot of pieces but i actually enjoy...      1
# 5128   I have planter facitius.  I was skeptical if t...      1
# 10118  My Breville juice fountain arrived with the pl...      1
# 17908  Well it is about darn time I find a headset th...      1
# 8030   I'm finding this unit amazing for doing jerky....      1
# 14481  These sneakers are great in every way accept t...      1
# 10526  My old microwave was a Goldstar which gave a g...      1
# 17889  Wear very thin, focused on inexpensive, whethe...      1
# 9479   Just wanted to let everyone know, if you do a ...      1
#
#                                           reviewTextEdit  text_length  \
# 2108   read previou review nervou qualiti item would ...          155
# 13974  lot piec actual enjoy assembl itit realli good...           84
# 5128   planter facitiu skeptic would work could size ...           68
# 10118  brevil juic fountain arriv plastic case top ma...          336
# 17908  well darn time find headset actual high qualit...          833
# 8030   find unit amaz jerki done within hour use jerk...          196
# 14481  sneaker great everi way accept run small broug...           79
# 10526  old microwav goldstar gave good year heavi dut...          914
# 17889  wear thin focus inexpens whether travel rain p...           71
# 9479   want let everyon know simpl search product typ...          207
#
#        predict_value_gpt2  predict_value_logistic  predict_value_NB  \
# 2108                    1                       1                 1
# 13974                   1                       1                 1
# 5128                    1                       1                 0
# 10118                   0                       0                 0
# 17908                   0                       1                 0
# 8030                    0                       0                 0
# 14481                   1                       1                 1
# 10526                   0                       0                 0
# 17889                   0                       1                 1
# 9479                    0                       0                 0
#
#        predict_value_bertlstm  predict_bagging  predict_bagging_binary
# 2108                        0         0.503184                       0
# 13974                       0         0.503184                       0
# 5128                        0         0.371550                       0
# 10118                       1         0.496816                       0
# 17908                       0         0.040050                       0
# 8030                        0         0.000000                       0
# 14481                       0         0.503184                       0
# 10526                       0         0.000000                       0
# 17889                       0         0.171683                       0
# 9479                        0         0.000000                       0

# %%
test_df[
    (test_df['predict_value_gpt2'] == 0) &
    # (test_df['predict_value_logistic'] == 0) &
    (test_df['predict_value_NB'] == 0) &
    (test_df['predict_value_bertlstm'] == 1)
]
# Out:
#        Unnamed: 0  index                     category  \
# 103           518  81772               Toys_and_Games
# 263          1374  59370             Home_and_Kitchen
# 268          1401   9022  Cell_Phones_and_Accessories
# 277          1460  75072          Sports_and_Outdoors
# 294          1574   3537  Cell_Phones_and_Accessories
# ...           ...    ...                          ...
# 19283       96540  29786   Clothing_Shoes_and_Jewelry
# 19384       97025  89488               Toys_and_Games
# 19452       97357  56745             Home_and_Kitchen
# 19811       99115  64127          Sports_and_Outdoors
# 19812       99120  53666             Home_and_Kitchen
#
#                                 summary  \
# 103    Sleek and appropriately smaller.
# 263                        Nice Toaster
# 268                      I prefer Zaggs
# 277                Worked great for us!
# 294         More like a Limited battery
# ...                                 ...
# 19283                        love style
# 19384         takes some getting use to
# 19452                   Much smaller...
# 19811  Exactly as pictured and expected
# 19812                            sifter
#
#                                               reviewText  class  \
# 103    A fine specimen of the SX3 FIghter from Mass E...      1
# 263    After purchasing a brand name I've never heard...      1
# 268    After reading an online review about these bei...      0
# 277    After reading the reviews we set the trap and ...      1
# 294    After using this battery for a week, i've noti...      0
# ...                                                  ...    ...
# 19283  not having a zipper blows. buttons get stuck. ...      0
# 19384  really hard to win! don't know why it doesn't ...      0
# 19452  than I expected.  I thought the height of it w...      0
# 19811  tl;dr? 16 matched sets, all different colors, ...      1
# 19812  to slow to siftmy hand got tired squeezing the...      0
#
#                                           reviewTextEdit  text_length  \
# 103    fine specimen sx fighter mass effect would lik...          477
# 263    purchas brand name never heard sunbeam return ...          608
# 268    read onlin review better zagg invisishield dec...          460
# 277    read review set trap put brick side prevent ro...          370
# 294    use batteri week notic significantli faster po...          187
# ...                                                  ...          ...
# 19283  zipper blow button get stuck zipper would star...           61
# 19384  realli hard win know show game like direct say...           52
# 19452  expect thought height would bit taller paid at...          151
# 19811  tl dr match set differ color low defect bad in...         1123
# 19812  slow siftmi hand got tire squeez mechanisma st...           95
#
#        predict_value_gpt2  predict_value_logistic  predict_value_NB  \
# 103                     0                       0                 0
# 263                     0                       1                 0
# 268                     0                       0                 0
# 277                     0                       1                 0
# 294                     0                       0                 0
# ...                   ...                     ...               ...
# 19283                   0                       0                 0
# 19384                   0                       1                 0
# 19452                   0                       1                 0
# 19811                   0                       1                 0
# 19812                   0                       1                 0
#
#        predict_value_bertlstm  predict_bagging  predict_bagging_binary
# 103                         1         0.496816                       0
# 263                         1         0.536866                       0
# 268                         1         0.496816                       0
# 277                         1         0.536866                       0
# 294                         1         0.496816                       0
# ...                       ...              ...                     ...
# 19283                       1         0.496816                       0
# 19384                       1         0.536866                       0
# 19452                       1         0.536866                       0
# 19811                       1         0.536866                       0
# 19812                       1         0.536866                       0
#
# [262 rows x 14 columns]

# %%
# imports
import json
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

import re

import nltk
nltk.download('stopwords')
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords

# plt.style.use('Solarize_Light2')
# %matplotlib inline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB, BernoulliNB

import joblib
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/zhuzilu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
loaded_cv = joblib.load('model/cvoptuna.pkl')
loaded_classifier = joblib.load('model/MultinomialNBoptuna.pkl')

# %%
loaded_classifier
# Out:
# MultinomialNB(alpha=0.3)

# %%
c = 0
for _ in loaded_cv.get_feature_names_out():
    print(_)
    c+=1
    if c > 100:
        break
# Out:
# aa
# aa batteri
# aaa
# ab
# abil
# abl
# abl charg
# abl find
# abl fit
# abl get
# abl keep
# abl make
# abl play
# abl put
# abl return
# abl see
# abl take
# abl use
# abl wear
# absolut
# absolut ador
# absolut beauti
# absolut love
# absolut perfect
# absorb
# abus
# ac
# accent
# accept
# access
# accessori
# accid
# accident
# accident drop
# accommod
# accomod
# accompani
# accomplish
# accord
# accordingli
# account
# accumul
# accur
# accuraci
# ach
# achiev
# acquir
# across
# acryl
# act
# act like
# action
# action figur
# activ
# actual
# actual bought
# actual fit
# actual get
# actual like
# actual look
# actual made
# actual make
# actual product
# actual size
# actual use
# actual work
# ad
# ad bonu
# adapt
# adaptor
# add
# add collect
# add littl
# add much
# addict
# addit
# addit collect
# address
# adequ
# adher
# adhes
# adida
# adjust
# adjust fit
# adjust strap
# admir
# admit
# admittedli
# ador
# adult
# advanc
# advantag
# adventur
# advert
# advertis
# advic
# advis
# aerob
# aesthet
# affect
# afford

# %%
loaded_classifier.feature_log_prob_
# Out:
# array([[-10.32434127, -10.97277741, -11.65458231, ..., -10.93545964,
#         -10.93545964, -11.09389298],
#        [-10.16589815, -10.81600782, -10.85332558, ...,  -9.84207039,
#         -10.81600782, -11.01830784]])

# %%
feature_names = loaded_cv.get_feature_names_out()
log_probabilities = loaded_classifier.feature_log_prob_

# Step 4: Create a DataFrame for better visualization
weights_df = pd.DataFrame(log_probabilities.T, index=feature_names, columns=["Negative(log prob)", "Positive(log prob)"])

# Sort by the highest weights for each class
sorted_weights = weights_df.sort_values(by=["Positive(log prob)", "Negative(log prob)"], ascending=False)

# %%
print(sorted_weights)
# Out:
#                   Negative(log prob)  Positive(log prob)
# great                      -5.723095           -4.563638
# use                        -4.741256           -4.638011
# love                       -6.030511           -4.677379
# one                        -4.640552           -4.715237
# like                       -4.840865           -4.807807
# ...                              ...                 ...
# dont wast money           -10.707201          -15.326867
# piec garbag               -10.707201          -15.326867
# realli want like          -10.707201          -15.326867
# want money                -10.707201          -15.326867
# terribl product           -10.767279          -15.326867
#
# [10000 rows x 2 columns]

# %%
print("Bottom Feature Weights of Features")
print(sorted_weights.tail(20))  # Top 10 features
# Out:
# Bottom Feature Weights of Features
#                   Negative(log prob)  Positive(log prob)
# way overpr                -10.678463          -13.860530
# cheap piec                -10.707201          -13.860530
# cost return               -10.767279          -13.860530
# total wast money          -10.033186          -15.326867
# zero star                 -10.194046          -15.326867
# dont wast                 -10.304656          -15.326867
# return window             -10.324341          -15.326867
# zipper broke              -10.385836          -15.326867
# huge disappoint           -10.429039          -15.326867
# return replac             -10.474194          -15.326867
# item return               -10.497559          -15.326867
# return immedi             -10.545995          -15.326867
# wast money time           -10.545995          -15.326867
# never recommend           -10.650529          -15.326867
# restock fee               -10.650529          -15.326867
# dont wast money           -10.707201          -15.326867
# piec garbag               -10.707201          -15.326867
# realli want like          -10.707201          -15.326867
# want money                -10.707201          -15.326867
# terribl product           -10.767279          -15.326867

# %%
x = loaded_cv.transform(['huge kershaw fan unhappi finish knife sever kershaw knive look fantast awar descript bead blast mean knife look unfinish kinda scratch unlik kershaw knive highli polish smooth finish knive knife shape size good meati seem get past condit look blade two cent']).toarray()

# %%
loaded_classifier.predict_proba(x)
# Out:
# array([[0.00310914, 0.99689086]])
